# %% [markdown]
# # Python Values, Variables, and Printing
#
# The support assistant starts with plain values. Run each cell, then change values and run again.

# %%
ticket_id = "TCK-1001"
customer = "Maya"
subject = "Charged twice for annual plan"
message = "I upgraded yesterday and my card shows two annual charges."

print(ticket_id)
print(customer)
print(subject)
print(message)
# Out:
# TCK-1001
# Maya
# Charged twice for annual plan
# I upgraded yesterday and my card shows two annual charges.

# %% [markdown]
# Variables let us reuse values without copying text everywhere.

# %%
summary = f"{ticket_id}: {subject}"
print(summary)

# %% [markdown]
# Try changing `subject` or `customer`, then rerun the cells.
